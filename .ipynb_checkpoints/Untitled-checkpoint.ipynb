# %%
import pandas as pd
import os

from bs4 import BeautifulSoup
from pandas import DataFrame
from requests_html import HTMLSession
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from time import sleep

def load_page(url: str, wait_time: int, batches: int, chromedriver_path: str,
              opts: Options) -> BeautifulSoup:
    '''
    The browser sometimes return different htmls, fortunately there is a
    small variation in patterns. As a workaround, this function tries to reload
    the page every time a pattern different from the reference
    html is returned.

    Parameters:
    -----------------------
    url :: str
        the url of the parent page

    wait_time :: int
        The pause time before the next scroll down is executed,
        allows the browser to load twelve more hotel cards

    batches :: int
        The number of batches loaded (12 per batch), each scroll
        adds 1 batch of hotel cards

    Returns:
    -----------------------
    hotel_cardsBS :: list of BeautifulSoup Object
        list containing immediate parent of the hotel cards and its children

    '''
    # launch driver load get initial page html, ...
    # ... and check if the same as reference html

    driver = webdriver.Chrome(chromedriver_path, options=opts)
    driver.maximize_window()
    driver.get(url)
    selector = 'body .resp-section .inner-section .resp-row .resp-col .main-inner section .h-listing .listings'

    page_init = driver.page_source
    soup_init = BeautifulSoup(page_init, 'html.parser')
    cardsBS4_init = soup_init.select_one(selector)

    if cardsBS4_init is None:
        # look at driver.navigate().refresh(), it might be better
        # cardsBS4_init is only none when the html loaded is different from ...
        # ... the referrence html, reload.
        driver.quit()
        load_page(url, wait_time, batches, chromedriver_path, opts)
    else:
        i = 1
        while i < batches:
            # this adds 12 more hotel cards per iteration, if i > 84, ...
            # the script stops, that is we end up with 1008 (hopefully- net ...
            # problems) hotel cards

            script = 'window.scrollTo(0, document.body.scrollHeight,)'
            # scroll down to the bottom
            driver.execute_script(script)

            # gives time for the second scrolldown, ...
            # ... adjust according to net speed.
            sleep(wait_time)
            i += 1

        print('load_page done')
        # the resulting html after scroll downs
        page = driver.page_source
        soup = BeautifulSoup(page, 'html.parser')
        hotel_cards_container = soup.select_one(selector)
        
        hotel_cards = hotel_cards_container.find_all('li', recursive=False)

        return hotel_cards # return list


def request(url: str, init_query: str, requests: HTMLSession) -> BeautifulSoup:
    '''
    Follows the same logic as the selenium page loader, but for vanilla soup
    objects. Reload page if the html of the page is different than that of the
    reference page. Keep reloading until html of query is equivalent to
    reference html.

    Parameter:
    ----------------------------------------------------------------------------
    url :: str
        the url of the parent page

    init_query :: str , this is the initial css selector to be used for
                  checking
        initial query with attribute names from reference html

    Return:
    ----------------------------------------------------------------------------
    soup_init :: bs4Object
        the parent page html, this is similar to the reference html

    Note:
    ----------------------------------------------------------------------------
        requests.get(url) randomly returns different html formats, fortunately
        the set of html formats returned is finite. Reload the page until the
        reference format is returned.
    '''
    page = requests.get(url)
    
    soup_init = BeautifulSoup(page.content, 'html.parser')

    # use this query uses attribute names similar to reference html, ...
    # ... it this is None, the html loaded is different
    check_query = soup_init.select_one(init_query)

    if check_query is None:
        # reload the html
        request(url, init_query, requests)
    else:
        # once init_query loads the expected attributes, return the soup
        return soup_init
   

def init_df() -> DataFrame:
    # features must be defined in the same order as the definitions ...
    # ... in Hotel class
    features = ['hotel_name', 'price', 'rating', 'loc', 'city',
                'province', 'landmarks', 'terminals',
                'rooms', 'ameneties', 'reviews']

    hotel_dataFrame = pd.DataFrame(columns=features)
    return hotel_dataFrame


def url_req() -> str:
    url = ('https://ph.hotels.com/search.do?resolved-location=COUNTRY%3A10'
           + '233139%3AUNKNOWN%3AUNKNOWN&destination-id=10233139&q-destina'
           + 'tion=Philippines&q-check-in=2021-10-10&q-check-out=2021-10-1'
           + '1&q-rooms=1&q-room-0-adults=2&q-room-0-children=0')

    return url

def add_hotels(cards: list, df: DataFrame):
    '''
    Add the attributes of one hotel to the hotel dataFrame
    '''
    for card in cards:
        Hotel(card, df)


def save_hotels(df: DataFrame):
    file = 'data/Hotel.csv'
    df.to_csv(file)


def extract_data() -> list:
    chromedriver_path = os.getcwd() + '\\chromedriver\\chromedriver.exe'
    opts = Options()
    opts.add_argument(' — headless')

    # initialize dataframe
    hotels = init_df()

    # returns of BeautifulSoup hotel cards
    hotel_cards = load_page(url=url_req(), wait_time=10,
                            batches=1,
                            chromedriver_path=chromedriver_path,
                            opts=opts
                            )
    add_hotels(hotel_cards, hotels)      # add hotels
    save_hotels(hotels)                  # save hotels dataFrame to csv

# %%
class Hotel:
    def __init__(self, hotel_card: BeautifulSoup, dataFrame: DataFrame):
        '''
        Initialize a hotel, where card is a bs4 Object,
        containing the hotel data

        note to self: classes can access global definitions, no need init class
        with requests object for indivPage
        and reviewPage
        '''

        # helper variables
        self.card = hotel_card
        self.address = self.get_address()

        individualPage = self.get_hotelPageSoup()
        reviewPage = self.get_reviewPageSoup(individualPage)

        # the features
        self.hotel_name = self.get_name()
        self.price = self.get_price()
        self.rating = self.get_rating()
        self.loc = self.address[0]
        self.city = self.address[-4]
        self.province = self.address[-2]
        self.landmarks = self.get_landmarks(individualPage)
        self.terminals = self.get_terminals(individualPage)
        self.rooms = self.get_rooms(individualPage)
        self.ameneties = self.get_amenities()
        self.reviews = self.get_reviews(reviewPage)

        # add to DataFrame
        self.add_hotel(dataFrame)

    def get_name(self) -> str:
        '''
        Returns:
            hotel_name :: str
        '''
        hotel_name = self.card['data-title']
        return hotel_name

    def get_price(self) -> int:
        '''
        Returns
            price :: int

        pricing(Php) for 2 adults, one night sta y.
        '''
        # returns the likes of 'P6,221'
        price = self.card.find('a', class_='price-link').get_text()
        # filter returns list of all chars in price ['P',',','6','7','8'], ...
        # ... loop over each element and

        # create a new list satisfying only i.isdigit, join this into a ...
        # ... string convert string into int

        price_int = int(''.join(i for i in filter(None, price) if i.isdigit()))

        return price_int

    def get_rating(self) -> float:
        '''
        Returns
            rating :: float
        '''
        rating = (self.card.find('strong',
                                 class_='guest-reviews-badge').get_text())

        # float(the digit chars and '.' in the list of chars of rating)
        rating_float = float(''.join(i for i in filter(None, rating) if
                                     (i.isdigit() | (i == '.'))))

        # filter() :: str -> [char]
        return rating_float

    def get_address(self) -> list:
        '''
        Returns
            address :: str

        full address of the hotel, via list with format
        [loc1, loc2, city, zipCode, province, country]
        '''

        address_ = self.card.find('span', class_='address').get_text()
        address = address_.split(', ')                     # to get the list

        # city has index -4 when from right to left, this is a list of locs ...
        # ... from city -> country
        address_cp = address[-4:]

        # concatenate the specific addresses
        address_sp = self.join_specificAdds(address[:-4])
        # address now has elements: [address_sp, city, zipCode, province, ...
        # ... country]
        address_cp.insert(0, address_sp)
        return address_cp

    def get_landmarks(self, individualPage: BeautifulSoup) -> list:
        '''
        Returns the list of all landmarks
        with format:
            landmark - distance
        '''
        selector = ('body div.resp-section main.inner-section '
                    + 'div#property-details '
                    + 'div#flexible-container-bottom '
                    + 'div.whats-around-content-landmarks-transport')

        landmarks = individualPage.select_one(selector)

        landmarks = landmarks.find(class_='whats-around-content landmarks')

        landmarks_col = [landmark.get_text() for landmark in
                         landmarks.select('div.landmarks-expandable-wrapper '
                                          + 'ul.landmark-list li')]

        return landmarks_col

    def get_terminals(self, individualPage: BeautifulSoup) -> dict:
        '''
        get dictionary of terminals where
        dict.key = transportation type
        dict.value = [Name of Terminal - distance from hotel]
        '''

        # cut the full query, into two parts ...
        selector = ('body div.resp-section main.inner-section '
                    + 'div#property-details '
                    + 'div#flexible-container-bottom '
                    + 'div.whats-around-content-landmarks-transport')

        transpo_soup = individualPage.select_one(selector)
        transports = transpo_soup.find(class_='whats-around-content transport')

        # categegory['class'] returns a list, regardless the first entry ...
        # ... is the actual category of transportation
        transport_cat = [category['class'][0] for category in
                         transports.select('ul')]

        # ... airport, train-station, etc

        # helper function,  returns the list of all terminals with category cat
        def terminal_query(cat): return ([station.get_text() for station in
                                          transports.select('ul.{0} li'
                                                            .format(cat))])

        transports_col = {category: terminal_query(category) for category in
                          transport_cat}
        return transports_col

    def get_rooms(self, individualPage: BeautifulSoup) -> int:
        '''
        Returns the number of rooms in the hotel
        '''

        # query was two long for one line, divided in to two parts
        hotelSize_query = ('#at-a-glance div.cont-wrap '
                           + 'div.fact-sheet-columns div.col-8-24 '
                           + 'div.info-box ul li')

        # there are two instances of ul li tags in html, select_one ...
        # always select first instance which is the one we need
        hotel_size = individualPage.select_one(hotelSize_query).get_text()
        # concatenated strings for shorter query in line

        room_count = [int(word) for word in hotel_size.split()
                      if word.isdigit()][0]

        # the extraction method follows from
        # hotel_size has initial value 'This hotel has N number of rooms'
        # .split() splits according to the presence of each word
        # the list comprehension checks all strings with digits, ...
        # ... in our case the room count, this is the same for all cases
        # need to add exceptions, to avoid errors

        return room_count

    def get_amenities(self) -> list:
        '''
        list of all amenities available to hotel
        '''
        amenities = self.card.select_one('.hmvt8258-amenities')
        amenities_col = [amenity.get_text() for amenity in
                         amenities.select('li')]

        return amenities_col

    def get_reviews(self, review_page: BeautifulSoup) -> list:
        '''
        Returns a list of the reviews for the hotel
        Each review is a dictionary and has the following items:

         'reviewer': name of reviewer
         'rating': rating given be reviewer
         'trip type': type of the trip; how long did the reviewer stay
         'comment': what the reviewer had to say in particular
        '''

        # helper variables and functions

        # helper functions
        def get_content(card, class_name):
            return card.find(class_=class_name).get_text()

        def to_float(content):  # converts strings to float
            return float(''.join(i for i in
                                 filter(None, content)
                                 if (i.isdigit() | (i == '.'))))

        # get the attribute as per class name assigned
        def review(card): return {'reviewer': get_content(card,
                                                          class_names[0]),
                                  'rating': to_float(get_content(card,
                                                                 class_names[1])
                                                     ),
                                  'trip type': get_content(card,
                                                           class_names[2]),
                                  'comment': get_content(card,
                                                         class_names[3])
                                  }

        # Names of the classes that point to an ...
        # ... attribute of a review card
        class_names = ['reviewer', 'rating-score', 'trip-type-nights',
                       'expandable-content description']

        review_cards = review_page.select('div.review-card')

        # get formatted card reviews for 15 reviews
        reviews = [review(card) for card in review_cards[0:15]]
        return reviews

    def add_hotel(self, dataFrame):
        '''
        Adds the hotel to a dataFrame

        Parameters
        -----------------------------
        dataFrame :: Pandas.DataFrame
        '''
        hotel = self.__dict__

        # remove unnecessary features
        hotel.pop('card')
        hotel.pop('address')

        dataFrame.append(hotel, ignore_index=True)

    # helper functions
    def get_hotelPageSoup(self) -> BeautifulSoup:
        '''
        Gets the individual hotel card
        '''

        # get the text in the attribute href
        href = self.card.find('a', class_='property-name-link')['href']
        # this is the link to the individual hotel information
        href_url = 'https://ph.hotels.com' + href
        # problem with 'link' + 'link' + 'link' notation, changed back to current format
        init_query = 'body div.resp-section main.inner-section div#property-details div#flexible-container-bottom div.whats-around-content-landmarks-transport'
        requests = HTMLSession()
        
        soup_href = request(href_url, init_query, requests)
        return soup_href

    def get_reviewPageSoup(self, idPage: BeautifulSoup) -> BeautifulSoup:
        '''
        Gets the review page from the indivdual card
        '''

        revPage_linkQuery = idPage.select_one('div#property-reviews div.see-all-reviews a')
        
        reviewPage_link = 'https://ph.hotels.com' + revPage_linkQuery['href']
        init_query = 'div.review-card'
        requests = HTMLSession()
        review_page = request(reviewPage_link, init_query, requests)

        return review_page

    def join_specificAdds(self, specific_address: str) -> str:
        '''
        there are instances where there are 3 separate specific address before
        city hence the need specific_address is a list of the addresses before
        the city
        '''
        specific_add = ''
        index = 1
        for i in specific_address:
            if index != len(specific_address):
                # add the first address and  ', ' to separate from next address
                specific_add += (i + ', ')
                index += 1
            else:
                # add the last specific address
                specific_add += i
                return specific_add

# %%
extract_data()

# %% [markdown]
# ## <b> Test for individual data

# %%
p = extract_data()
# Out:
# load_page done

# %%
p
# Out:
# [<li class="hotel sponsored" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="113079" data-image-id="7151684" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="1|113079|EC||LOCAL|4250" data-os-property-id="113079" data-os-property-image-id="7151684" data-os-property-rank="0" data-pimms="DoubleStamps|D13|TESCO" data-provider-type="LOCAL" data-title="The Heritage Hotel Manila"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="sponsored-badging">Ad</span><a class="property-name-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUya6rSgz8m7O65NANBPpK0RNTIBOBhClsUEMDgTCEmeTrb855XliqcpUte-H7MDz7v9_f8zyvkgyTKemGvM_rbBU31feAn_33BL7l8r8h6Qc36fq8qc8fUZeTZMOiNVjRfxDNfjLP_QIeAm4F_ggQCB8k8ACs4B8BQWHFfIT0L8mw_K_t1ycgDv74EIK_yo_9U-Mh-nRBPFj_IGH9o0SI_akBGnA_I5AgsP9D4UN_dbh-bMBXjGuSEzwkeqWNOdlESUwnDI0ozMSIYuOUp3BKEMUQBAGNWT4h9NfQ4fjxWVrBA96In1CVRZ8zzYQ6FT3ThmgDoRwpyy7GpHkeCTyfA67lH7Wuc8O3lyiS9KCY6-08idpwIWazs18AMXUER9xcFt_rIzUEU2QGtqTbV3zet4IXNuvxlrLbUy-hGPdzY7T3rpKGSQkr-bQmXZ6bJ-zrKSqc4-k4HJSrSGzqdgu5oPcOkTx1OsH3u2nLLKrLR7fGil88_HWH8-sO1PYame93TcLXS-_GvECSkdLPJiQhXSXDoLgOGNy3W10tKJzHRGwc6DYwkiroRRn3OVEWm6H0kJTyaWVUidZ34I9cyk54W0KzY7mC7LZuOVlz9wmqMjPfq-TZPAoWxvp573ZzrV23SABEzAa7KFQuqlIJYpu9FHCruUlhR1SRMshg-NFEO7IX5edli--abY_LvVuWp9HHUh3Mj9gtg716YDpDag7KNlsYWmzbffpcWIlvp6z2YVa-S4ElV3lnWrZyGJw9cG7ZXOLnO8tBoO2Ewi_Som_wOMdmriLhElon9OR6MXvsr4HZysDwpiNhWcM8t9G8nPUeCiVi3nKntv61emk9uK951j5zdomW_XZZQC5Zo2EZlUqy8JbruWpc0fqWjXIqv931znMO0ksZ_JQ7xPPekSmaMvaBhbUZmpwTrpHFDqqoMI7Hz2rv1rssXgIgK0gPW6jsZlSmiArdRwaRPFM5ErAfxdxhEhmz826qLAVdPTnNPVuDvhgnRhUc3U0GfDCPGWkfVVwbTtEdt16UnOf3UgxTWRkLoVmT9c8neQTj_kS0Vww13zzrNWgXRlWSwFl7y7tCylWpaFXiHjyuAHtzn8KdVhxaM_ArttLOvgeou90sXtx2fkLxRiG2iqBd_JN0tXCZ1S_RCl6JqqJCO_AW1WKHe4tN4VQT9JbulGaq25LlhJo7tw30pI0WoqditRUekmm47cs4cUKZi8KFbyuwS0-3On17wTacovc2c87cjoSLSpc0GC9gZ4Squ4tdQPbBS7hxhkQvd3VY3o9b6IK-z_Pu9dxrMbHO3fVpoqJDx2su3U6TRWJ95rhgG5OE1ztwoHpx3my--rIZ-o1-vYTi17Pp8-Hz-z4fJkpw3NS7vh8TsoE0BBTNUgDagPkLmb8s_Br7pNuZGwDgCiBhBSFcIeEfAGg6iGkFAAA.&amp;targetUrl=H4sIAAAAAAAAAEWMsQ6CMBBA_-a2C3fFhDhcXEQm44CJ4lbbJm3EFkv5f4mDLG9671U-MdfU7KvDpIXhg8Y788K0FFGkGJmQGYp-inWzyWEqIcVVyym9kVDbZSyzKBi6k_Du34e45QTn7rq-b5f2x6M08OjvQtAPrdTbzPgw2uyi0BfuumS5lwAAAA.." target="_blank">The Heritage Hotel Manila</a></h3><address class="contact"><span class="address" dir="ltr">Roxas Boulevard, Corner Of Edsa, Pasay, Manila, 1300, Philippines</span></address><figure class="image"><a class="property-image-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUya6rSgz8m7O65NANBPpK0RNTIBOBhClsUEMDgTCEmeTrb855XliqcpUte-H7MDz7v9_f8zyvkgyTKemGvM_rbBU31feAn_33BL7l8r8h6Qc36fq8qc8fUZeTZMOiNVjRfxDNfjLP_QIeAm4F_ggQCB8k8ACs4B8BQWHFfIT0L8mw_K_t1ycgDv74EIK_yo_9U-Mh-nRBPFj_IGH9o0SI_akBGnA_I5AgsP9D4UN_dbh-bMBXjGuSEzwkeqWNOdlESUwnDI0ozMSIYuOUp3BKEMUQBAGNWT4h9NfQ4fjxWVrBA96In1CVRZ8zzYQ6FT3ThmgDoRwpyy7GpHkeCTyfA67lH7Wuc8O3lyiS9KCY6-08idpwIWazs18AMXUER9xcFt_rIzUEU2QGtqTbV3zet4IXNuvxlrLbUy-hGPdzY7T3rpKGSQkr-bQmXZ6bJ-zrKSqc4-k4HJSrSGzqdgu5oPcOkTx1OsH3u2nLLKrLR7fGil88_HWH8-sO1PYame93TcLXS-_GvECSkdLPJiQhXSXDoLgOGNy3W10tKJzHRGwc6DYwkiroRRn3OVEWm6H0kJTyaWVUidZ34I9cyk54W0KzY7mC7LZuOVlz9wmqMjPfq-TZPAoWxvp573ZzrV23SABEzAa7KFQuqlIJYpu9FHCruUlhR1SRMshg-NFEO7IX5edli--abY_LvVuWp9HHUh3Mj9gtg716YDpDag7KNlsYWmzbffpcWIlvp6z2YVa-S4ElV3lnWrZyGJw9cG7ZXOLnO8tBoO2Ewi_Som_wOMdmriLhElon9OR6MXvsr4HZysDwpiNhWcM8t9G8nPUeCiVi3nKntv61emk9uK951j5zdomW_XZZQC5Zo2EZlUqy8JbruWpc0fqWjXIqv931znMO0ksZ_JQ7xPPekSmaMvaBhbUZmpwTrpHFDqqoMI7Hz2rv1rssXgIgK0gPW6jsZlSmiArdRwaRPFM5ErAfxdxhEhmz826qLAVdPTnNPVuDvhgnRhUc3U0GfDCPGWkfVVwbTtEdt16UnOf3UgxTWRkLoVmT9c8neQTj_kS0Vww13zzrNWgXRlWSwFl7y7tCylWpaFXiHjyuAHtzn8KdVhxaM_ArttLOvgeou90sXtx2fkLxRiG2iqBd_JN0tXCZ1S_RCl6JqqJCO_AW1WKHe4tN4VQT9JbulGaq25LlhJo7tw30pI0WoqditRUekmm47cs4cUKZi8KFbyuwS0-3On17wTacovc2c87cjoSLSpc0GC9gZ4Squ4tdQPbBS7hxhkQvd3VY3o9b6IK-z_Pu9dxrMbHO3fVpoqJDx2su3U6TRWJ95rhgG5OE1ztwoHpx3my-- ...
#  <li class="hotel sponsored" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="384361024" data-image-id="372958175" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="2|384361024|EC||LOCAL|6561" data-os-property-id="384361024" data-os-property-image-id="372958175" data-os-property-rank="1" data-pimms="DoubleStamps|TESCO" data-provider-type="LOCAL" data-title="Conrad Manila"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="sponsored-badging">Ad</span><a class="property-name-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVU2Y6jWgz8m34a0uewBM5I0RWEhJ1AWEJ4QWwh7Gsg8PWT7usHS1WusmXJ8nOauvHv9_eyLLs0C5M5HaZ8zJtsF7f19xR24_cMv4_Vf1M6Tm46jHnbXD6iIU_SA4n2cAf-IEB-Mk39AhqH1A7-YXDIfBBDQ7jD_zAIZ3bERwh-SYKkf22_PgZR-I8PIfxX-bF_ajSOPl0QDfc_iNn_KBEif2oQQOpnBGIY8n_IfOivIWzKA_4Vh02SJ-GUirXwypNDlMYgJQDCQiJGGBk_aCx8JAgjEoRDEJJ0moCvaQjj8rM0H07hgf3E6eQyF_8xPzg60uce5VLvZdbq71N-NNUZrExQMkl2B6rXPQFum9WFwDKL3csWS2IifA9qHBXltWTZVWAKY5ozU3NmgBmmMrXr-_5MY6u8E0EQRJzJU2HAXdanw7Jo4OsSNmVJibbcVWHX1mepziMJaa3pSnTnFx5noA3YR5r1SL4n6gnXlM04Co8kOAJaKWo8LIRO3SiMFLRNbSReV5PUdRz29FgCIBBI4A2Jt4I33quwiIWuZsjnumfxuy9MrmYlJX10Ga5tKftY23ZMESJxlPZg39vmoDqJd_O3Xjjy8s2lUK16UznM1Rg_dKDInOvePN3P-cW9mr1xS9lRq2SHzqX8dH4_ulkKbnN3sqDet5Qnk-w7JxNQndjoes-wTp_YZ_osqZ4uYGLR2MszKIMZ8Cp5Xr2e7PvkrExRfzqNa1e08vY5F35GbMxKyHRqm9_YqFwT5Z7xTthY1um1no6MHAmnM38nRr1nXmH-Wn1B1JbJ05dTROnMDC6uIYPHIr7KSdEL9XECeQS8pn63lK54TbGdn9MKAerOezk5ZS8p9eZKnmoZOVtY4dJVKNj9wFmiz5pHbSCb5WZd3DLnK4le5HNFlrGi6tkKFjYZoGf6oRtqtJAHpKIyzSY-ubdOTRPNyQ90TbaNNilDiAMNc553LTCeWI3BMA_296pqFZvBjWLLUIquV-6SW8v7GmnJkBeciLm4b-nQWY071V8c1VAjw3C1RZAVhX08a0mCl1KbppsZHq9UBTNpC1f7htVyA_kjZ180VC5eJShvFtWyTyJwvY3BAErLv2fk03W044KGm122I52pfWMQsO32cXotAthxm6PvGR1_JaaQ3_rWsbcBatw7mBLgzEWkzqM1uJh8yR6vlG7ysBasuDELUN49XkrE4SWvBtFTsu-IAojPQiGT5xmvH3WeO6KI2y-nFfq7aoA2sCa3ToglF99rR2jLuUjnrKyHp3ps3ddQd9aG8GT1Raasqgt74dPKhD7IkW7KiheZp5AgHhZPBGf_OnKLEg1SJ5Xu6l38pL4fW7vPs8Pha6zaaTyI1jXgvrp2zKfP7_t8mCgN47aRxvGVJgcc4BADJAZxGxJ_ceIviX-9xnSQjAOE-A4iZofj-A4x_wA8EJJxaQUAAA..&amp;targetUrl=H4sIAAAAAAAAAEXMsQ6CMBSF4be5W8O9baMuNy4ik3HARHGrpUkbsMVS3l_iIMuZ_u9UPqmDVjtCqavjZFjCR1jv7CDSUliiJEEoiKCYF_dutjlMJaS4Zjmlt0Bh-mUs8wq75syk_z7EjSNcmhsT3K_1b0-8h2f7YIS2q1ltZ9aHsc8uMn4BAnAw0JoAAAA." target="_blank">Conrad Manila</a></h3><span class="hotel-badge" data-badge-type="topHotel">Top Hotel</span><address class="contact"><span class="address" dir="ltr">Seaside Boulevard, Corner of Coral Way, Mall of Asia Complex, Pasay, Manila, 1300, Philippines</span></address><figure class="image"><a class="property-image-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVU2Y6jWgz8m34a0uewBM5I0RWEhJ1AWEJ4QWwh7Gsg8PWT7usHS1WusmXJ8nOauvHv9_eyLLs0C5M5HaZ8zJtsF7f19xR24_cMv4_Vf1M6Tm46jHnbXD6iIU_SA4n2cAf-IEB-Mk39AhqH1A7-YXDIfBBDQ7jD_zAIZ3bERwh-SYKkf22_PgZR-I8PIfxX-bF_ajSOPl0QDfc_iNn_KBEif2oQQOpnBGIY8n_IfOivIWzKA_4Vh02SJ-GUirXwypNDlMYgJQDCQiJGGBk_aCx8JAgjEoRDEJJ0moCvaQjj8rM0H07hgf3E6eQyF_8xPzg60uce5VLvZdbq71N-NNUZrExQMkl2B6rXPQFum9WFwDKL3csWS2IifA9qHBXltWTZVWAKY5ozU3NmgBmmMrXr-_5MY6u8E0EQRJzJU2HAXdanw7Jo4OsSNmVJibbcVWHX1mepziMJaa3pSnTnFx5noA3YR5r1SL4n6gnXlM04Co8kOAJaKWo8LIRO3SiMFLRNbSReV5PUdRz29FgCIBBI4A2Jt4I33quwiIWuZsjnumfxuy9MrmYlJX10Ga5tKftY23ZMESJxlPZg39vmoDqJd_O3Xjjy8s2lUK16UznM1Rg_dKDInOvePN3P-cW9mr1xS9lRq2SHzqX8dH4_ulkKbnN3sqDet5Qnk-w7JxNQndjoes-wTp_YZ_osqZ4uYGLR2MszKIMZ8Cp5Xr2e7PvkrExRfzqNa1e08vY5F35GbMxKyHRqm9_YqFwT5Z7xTthY1um1no6MHAmnM38nRr1nXmH-Wn1B1JbJ05dTROnMDC6uIYPHIr7KSdEL9XECeQS8pn63lK54TbGdn9MKAerOezk5ZS8p9eZKnmoZOVtY4dJVKNj9wFmiz5pHbSCb5WZd3DLnK4le5HNFlrGi6tkKFjYZoGf6oRtqtJAHpKIyzSY-ubdOTRPNyQ90TbaNNilDiAMNc553LTCeWI3BMA_296pqFZvBjWLLUIquV-6SW8v7GmnJkBeciLm4b-nQWY071V8c1VAjw3C1RZAVhX08a0mCl1KbppsZHq9UBTNpC1f7htVyA_kjZ180VC5eJShvFtWyTyJwvY3BAErLv2fk03W044KGm122I52pfWMQsO32cXotAthxm6PvGR1_JaaQ3_rWsbcBatw7mBLgzEWkzqM1uJh8yR6vlG7ysBasuDELUN49XkrE4SWvBtFTsu-IAojPQiGT5xmvH3WeO6KI2y-nFfq7aoA2sCa3To ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="974390240" data-image-id="66418750" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="3|974390240|EC||LOCAL|1026.79" data-os-property-id="974390240" data-os-property-image-id="66418750" data-os-property-rank="2" data-pimms="Oceanviewv1|DoubleStamps|Privatebeachv1|D13|HRW|TESCO" data-provider-type="LOCAL" data-title="Pangulatan Beach Resort"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho974390240/?pa=3&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Pangulatan Beach Resort</a></h3><address class="contact"><span class="address" dir="ltr">Sitio Pangulatan, Liminangcong, Taytay, Palawan, 5312, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho974390240/?pa=3&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Pangulatan Beach Resort, Taytay" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/31000000/30420000/30418500/30418445/0e6f05fb_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Pangulatan Beach Resort, Taytay" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/31000000/30420000/30418500/30418445/0e6f05fb_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Pangulatan Beach Resort, Taytay" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/31000000/30420000/30418500/30418445/0e6f05fb_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">2.5-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho974390240/?pa=3&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Taytay</a><ul class="property-landmarks"><li>430 km to Subic Bay</li><li>430 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity pool">Pool</li><li class="hmvt8258-amenity parkingOptions">Free parking</li><li class="hmvt8258-amenity petFriendly">Pet-friendly</li><li class="hmvt8258-amenity airportTransfer">Airport transfer</li><li class="hmvt8258-amenity spa">Spa</li><li class="hmvt8258-amenity restaurant">Restaurant</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-very-good">Very good 8.0</strong><a class="guest-reviews-link reviews-link" href="/ho974390240/?pa=3&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">4 reviews</span><span class="full-view">4 Hotels.com guest reviews ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Guest House" data-hotel-id="595231" data-image-id="38156285" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="4|595231|EC||LOCAL|352.68" data-os-property-id="595231" data-os-property-image-id="38156285" data-os-property-rank="3" data-pimms="DoubleStamps|D13" data-provider-type="LOCAL" data-title="Casa Dayang Kalibo"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="vr-badge">Guest house</span><a class="property-name-link" href="/ho595231/?pa=4&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Casa Dayang Kalibo</a></h3><address class="contact"><span class="address" dir="ltr">Toting Reyes St. Villa Salvacion, Kalibo, Boracay, 5600, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho595231/?pa=4&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Casa Dayang Kalibo, Kalibo" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/16000000/15170000/15169800/15169792/5655f494_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Casa Dayang Kalibo, Kalibo" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/16000000/15170000/15169800/15169792/5655f494_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Casa Dayang Kalibo, Kalibo" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/16000000/15170000/15169800/15169792/5655f494_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">2-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho595231/?pa=4&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Estancia</a><ul class="property-landmarks"><li>410 km to Subic Bay</li><li>350 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity parkingOptions">Free parking</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-good">Good 7.0</strong><a class="guest-reviews-link reviews-link" href="/ho595231/?pa=4&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">2 reviews</span><span class="full-view">2 Hotels.com guest reviews</span></a></div></div></div><aside class="pricing resp-module"><div class="price"><div class="scarcity-message">We have 1 left at</div><a class="price-link" href="/ho595231/?pa=4&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&am ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="940450912" data-image-id="58710011" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="5|940450912|EC||LOCAL|800" data-os-property-id="940450912" data-os-property-image-id="58710011" data-os-property-rank="4" data-pimms="DoubleStamps|D13|TESCO" data-provider-type="LOCAL" data-title="Bugang Riverside Inn"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho940450912/?pa=5&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Bugang Riverside Inn</a></h3><address class="contact"><span class="address" dir="ltr">Barangay Mag-aba, Pandan, Antique, Pandan, Antique, 5712, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho940450912/?pa=5&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Bugang Riverside Inn, Pandan" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/30000000/29360000/29357900/29357841/cbaa2443_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Bugang Riverside Inn, Pandan" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/30000000/29360000/29357900/29357841/cbaa2443_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Bugang Riverside Inn, Pandan" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/30000000/29360000/29357900/29357841/cbaa2443_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">2.5-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho940450912/?pa=5&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Pandan</a><ul class="property-landmarks"><li>390 km to Subic Bay</li><li>330 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity parkingOptions">Free parking</li><li class="hmvt8258-amenity petFriendly">Pet-friendly</li><li class="hmvt8258-amenity airportTransfer">Airport transfer</li><li class="hmvt8258-amenity restaurant">Restaurant</li><li class="hmvt8258-amenity bar">Bar</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-good">Good 7.4</strong><a class="guest-reviews-link reviews-link" href="/ho940450912/?pa=5&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">3 reviews</span><span class="full-view">3 Hotels.com guest reviews</span></a></div></div></div><aside class="pricing resp-module"><div class="price"><div class="scarc ...
#  <li class="ad-placement-wrap"><meso-display-ad class="ad-div" experiments="MeSo_GPT_SRA" height="60" mediaquery="only screen and (min-width: 599px) and (max-width: 849px)" path="/23171577/hotels.ph_en/hotels/results/IS1" slot="IS1_468x60" uci="IS1_468x60" width="468"></meso-display-ad><meso-display-ad class="ad-div" experiments="MeSo_GPT_SRA" height="50" mediaquery="only screen and (max-width: 599px)" path="/23171577/hotels.ph_en/hotels/results/IS2" slot="IS2_300x50" uci="IS2_300x50" width="300"></meso-display-ad></li>,
#  <li class="hotel sponsored" data-accommodation-type="_ACC_TYPE_NAME@Apart-hotel" data-hotel-id="478447" data-image-id="26826455" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="6|478447|Dual||LOCAL|10400" data-os-property-id="478447" data-os-property-image-id="26826455" data-os-property-rank="5" data-pimms="DoubleStamps|D13|TESCO" data-provider-type="LOCAL" data-title="Ascott Bonifacio Global City Manila"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="sponsored-badging">Ad</span><span class="vr-badge">Aparthotel</span><a class="property-name-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUybKqShD8m7O6eKBphr4RxgsQFRSRSQQ3RgPNqIDM-PXXc14tKiIrM6siN5X1fdP9_f6epmlFUhyPpO3zLq_SVVQ_v3vcdN8j8715_NeTrvdI2-V1df6I2jwma4h4ZkX_QTT8dIH7BQJguBXzRwSM-EGiwDAr8EdEQFyxHyH9O2Sh8Gv79YmIAz8-hMCv8mP_cAJAny1IYPgfJPI_SoTgD8fQDPdzAoki_B-Kn_FXi6tyzX5FuIrzGPdEfe6HPF6HJKIJSyMKsxGiYJQIFE5iRLExAgyNoUBi-qtvcVR-Qiu4x2vpU9st4ehRCjhNkFyXrve5FFHUvQDvmVXfs9zXtraryvciLMlJu-_okW03ROSFRFJM4RzzHpzx-zhr1Fipqej53E6-jk7gw-XYKMyOF6eDvEsnGlPH_qhYsTf6oq08cGJJXVRyvj0Z2Moq2X6rQ6l3t7Dd0vEF75AUGpvRZ45Hzd1plmuZe6xDyvFHM1qo7etR6Gr_DGPcBJDXSIF0t-KUV6I6Vz7f3geHcnXlHZTpdk_4xSaGPiDdd_HbW-j-EtwuxEvBfqzz1F9kQ4r85YBsERuHs8tcrsjkZp230SRtg_HKPLiKk7pDqAt8NsL8xMt0KdpzsHsUbeHFzX1o98QstrNUZwLrsW8vvsWyqrUpr9HLsNfyKyF5MunEqUlyR_mSnoPqwNCjqdHnDV1SzsNZDlPmTqaX4HB31qJrHrGcyIpOmC3MdHMPKHTdEHCW6022wL2nzgozUiVJbjpK7JKbEL3qvrpPi1g5zfFE9T47FCcBUSZf6VY95kh-u9ZML5auWyjljOQWipVXPhYZ3OV8W7_oFINrLWRmQGn9WxosvyyC6wY8I3j3L1C839UqpZVZ66fDQ6cbnT6fju3kNWkjAXYaKb1m53s-Gb7XFeclZJoFPDdQYtBVqudAn7e1FyW-ur8yxJ2TAp4RJdVdFIsd4epCJQq_nSz1Kt6X4abY6qt1sazkMzaOVVwelaTTg3CnMADOZXaxg86Q-d1ZzeAFPSDsu4z3rOxMN8Qs-3su-na6oQxjHgRD7mRemPPLoEEMneMbPXnPF9iuDqTXoVoG0AWuq11AM7feEj4gvxj1KbLdQbQRtd-VRpHVT2mbJTM3bWInE0_7bCMYdUqoAUZd66UMA27hcuNvG0GB_cvFZjrl-SsL04eSH5OrhJagJuxTVwzr4E_ejSvSi7F02cuEPZvXLFFkV3lBZxHG4lg7GuWiaD7Z56yJDcVTJ1hd9zdt7nyu2LHbbFtxb65Xbs-HtUlLAzWn5NXKklYElxBgxOpJpMcnp_Gjt1Co-HZCrKDEyshdjjGo3JekbpgivBjTev3VPeq-W6uOfd98NXWX95_ft-a_QoKjutK6biDxGtCAoWhIMcBl2L-A_QvB19CRVjPXn-grBokrAMAKif8AYkyB22kFAAA.&amp;targetUrl=H4sIAAAAAAAAAEWMsQ7CIBQA_-ZtL30gEZcXF2sn41ATrRsCCcQKldL_1zjY5aa7a0JWeqeUbvaT4S280QZvn5iXypKkQEEoBFTzYOdnW-JUY05freT8QkLjlrHOLGHojizUv49pzQlO3YUFXM_tjwfWcO9vTNAPLW_WmQ1xdMUnpg_bY-RMlwAAAA.." target="_blank">Ascott Bonifacio Global City Manila</a></h3><span class="hotel-badge" data-badge-type="lovedByGuests">Loved by guests</span><address class="contact"><span class="address" dir="ltr">28th Street corner 5th Avenue, Bonifacio Global City, Taguig, Manila, 1634, Philippines</span></address><figure class="image"><a class="property-image-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUybKqShD8m7O6eKBphr4RxgsQFRSRSQQ3RgPNqIDM-PXXc14tKiIrM6siN5X1fdP9_f6epmlFUhyPpO3zLq_SVVQ_v3vcdN8j8715_NeTrvdI2-V1df6I2jwma4h4ZkX_QTT8dIH7BQJguBXzRwSM-EGiwDAr8EdEQFyxHyH9O2Sh8Gv79YmIAz8-hMCv8mP_cAJAny1IYPgfJPI_SoTgD8fQDPdzAoki_B-Kn_FXi6tyzX5FuIrzGPdEfe6HPF6HJKIJSyMKsxGiYJQIFE5iRLExAgyNoUBi-qtvcVR-Qiu4x2vpU9st4ehRCjhNkFyXrve5FFHUvQDvmVXfs9zXtraryvciLMlJu-_okW03ROSFRFJM4RzzHpzx-zhr1Fipqej53E6-jk7gw-XYKMyOF6eDvEsnGlPH_qhYsTf6oq08cGJJXVRyvj0Z2Moq2X6rQ6l3t7Dd0vEF75AUGpvRZ45Hzd1plmuZe6xDyvFHM1qo7etR6Gr_DGPcBJDXSIF0t-KUV6I6Vz7f3geHcnXlHZTpdk_4xSaGPiDdd_HbW-j-EtwuxEvBfqzz1F9kQ4r85YBsERuHs8tcrsjkZp230SRtg_HKPLiKk7pDqAt8NsL8xMt0KdpzsHsUbeHFzX1o98QstrNUZwLrsW8vvsWyqrUpr9HLsNfyKyF5MunEqUlyR_mSnoPqwNCjqdHnDV1SzsNZDlPmTqaX4HB31qJrHrGcyIpOmC3MdHMPKHTdEHCW6022wL2nzgozUiVJbjpK7JKbEL3qvrpPi1g5zfFE9T47FCcBUSZf6VY95kh-u9ZML5auWyjljOQWipVXPhYZ3OV8W7_oFINrLWRmQGn9WxosvyyC6wY8I3j3L1C839UqpZVZ66fDQ6cbnT6fju3kNWkjAXYaKb1m53s-Gb7XFeclZJoFPDdQYtBVqudAn7e1FyW-ur8yxJ2TAp4RJdVdFIsd4epCJQq_nSz1Kt6X4abY6qt1sazkMzaOVVwelaTTg3CnMADOZXaxg86Q-d1ZzeAFPSDsu4z3rOxMN8Qs-3su-na6oQxjHgRD7mRemPPLoEEMneMbPXnPF9iuDqTXoVoG0AWuq11AM7feEj4gvxj1KbLdQbQRtd-VRpHVT2mbJTM3bWInE0_7bCMYdUqoAUZd66UMA27hcuNvG0GB ...
#  <li class="hotel sponsored" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="1130186432" data-image-id="489256168" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="7|1130186432|EC||LOCAL|5940" data-os-property-id="1130186432" data-os-property-image-id="489256168" data-os-property-rank="6" data-pimms="DoubleStamps" data-provider-type="LOCAL" data-title="Hilton Clark Sun Valley Resort"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="sponsored-badging">Ad</span><a class="property-name-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUx5KrSgz9m1lde2hy3yrXK5NswBgw4LShGpocTcZffz3ztFDVkc5RWEjpMLT93-_veZ63UYLwFHVD1md1sg2b6ntAbf89gW-x_G-I-uEadX3W1OaH1GU42tGQBVviDyToj-eYX8CRgNmCPzwJ-A_iOQC25B8ekvyW-hCJ3yBFc7-yXx0PGfJHByH5y_zIPzmOhJ8qkAPsD-LZHyaE9E8OEID5aQF5nv4f8p_wV4fqYkd_hajGGUZDdKwOY4Z3QRQSEUXADaJCuKHDmNugGMMNhSEJCERzESa-hg6FxWdpCQ1ot_-YfGz9I7fm3WG4dCnAzzNS_FdvBSmn6Y0ykpcykKwA5DxIykSokQOhN_KEYUO10ZRT5Ice1-6TupqcyfIVrlqc_S2dBzIIRMMyIt1aVJjfpPRk68NleVSP0Zk0Ky90IO0X8h3XeuwvmN0UWpzKLl3g15j7rpdNYuDQiXbSypucLr4mssJMht6zU53O9mTNIN5SLPsH3Cpia_ZXzt_Llk-ttilExpE6RJ0VCxlHFKOtCC-nTlxfPR660c3CvOd1X0nmjjprq8z4fhDy-La829ujJnN1evIStYbeoGd87BOBTR3jDbwRixcX6vKMXt7gxswVQASSQBdTN0Kk2bn1S217Ner0ST_cxWoie8EJBIkF58cbnPZ26LZ8pr9Nob34D3QuU6ZZ4UUOnuKNfyyPvngp2Wjqnh8xCW-urSpd3hTuTjiWoud5oGrVcdsj3TzOwnzANUfn-lENbfva3c96vbr4-cxWblVWfM1PR56LaNvy9u_jODUN_67lmpp6BVyuYcmivhbwygyxV6bSJn6EbK9a-_fiGU4hqnDib8zZTdSHnq4PlvWVa3V6j2u56BXMErQPKIs2PB_BQSbcVFiFMDjq0q0wI-blKJsQ9cDIp4fjc5V2iNb1mIveen69RBiyQkrkr6pylpwZNVPg_K6tXkkBZvw89vd6OVuN7adhLGEpbGZbvfmmIrrJuV83ICVLplYDqZp5jqKbE93teSd7CtQdd8Kl6RG7TEApYP0eq6ixnocxRKqt57CTUTtIoSbJiD4JenvIo9OQV9gx0Emw0vIwmfNTEa3sbCOPMA4iPjCkJuUcVgtVi21GdOwWSgAQTAPnYmHr-rwy55oon4jp5IqVeAdKPDabmx7BqqutO1rNe1AxVmDo7Sl03iJ5FSZuXxrtqblj4Dm-WY98ge9vU2mSjcYh1jGucP7cmBPy_it6F4fOqGN_Gh9XvzRX43olY_s229rQlk2DvdXUHSlkBp8dYaVlhqxy-SZ5mZxT1tf8Lu_Xbkb6M7EtJqjTy70yPgO4XuwDLdAVTbLo5JK6-93uqy-bod8dnYsvfbVNnw2f37fjvoIIhU2t9v0Y4R1JkGBD0BtAuoD6S1J_afJr7KNOtXYAkFsA-S1JklvI_wNYMf6KaQUAAA..&amp;targetUrl=H4sIAAAAAAAAAEWNsQ7CIBRF_-ZtpO9Boy4vLtZOxqEmWjcEEkgrVEr_38bBLme6557KJyKFdNjVSlbHSfMePsJ4ZwaRlsISJQlCQQRFv9i62eQwlZDiOsspvQUKbZexzCyhb89M9d8PcdMRLu2NCe7X5sfT2nl2D0bo-obVdmZ8GG12kfELl2zcPpsAAAA." target="_blank">Hilton Clark Sun Valley Resort</a></h3><address class="contact"><span class="address" dir="ltr">Clark Freeport Zone, Mabalacat City, Pampanga, 2023, Philippines</span></address><figure class="image"><a class="property-image-link" href="/travelads/trackredirect.html?trackingUrl=H4sIAAAAAAAAACVUx5KrSgz9m1lde2hy3yrXK5NswBgw4LShGpocTcZffz3ztFDVkc5RWEjpMLT93-_veZ63UYLwFHVD1md1sg2b6ntAbf89gW-x_G-I-uEadX3W1OaH1GU42tGQBVviDyToj-eYX8CRgNmCPzwJ-A_iOQC25B8ekvyW-hCJ3yBFc7-yXx0PGfJHByH5y_zIPzmOhJ8qkAPsD-LZHyaE9E8OEID5aQF5nv4f8p_wV4fqYkd_hajGGUZDdKwOY4Z3QRQSEUXADaJCuKHDmNugGMMNhSEJCERzESa-hg6FxWdpCQ1ot_-YfGz9I7fm3WG4dCnAzzNS_FdvBSmn6Y0ykpcykKwA5DxIykSokQOhN_KEYUO10ZRT5Ice1-6TupqcyfIVrlqc_S2dBzIIRMMyIt1aVJjfpPRk68NleVSP0Zk0Ky90IO0X8h3XeuwvmN0UWpzKLl3g15j7rpdNYuDQiXbSypucLr4mssJMht6zU53O9mTNIN5SLPsH3Cpia_ZXzt_Llk-ttilExpE6RJ0VCxlHFKOtCC-nTlxfPR660c3CvOd1X0nmjjprq8z4fhDy-La829ujJnN1evIStYbeoGd87BOBTR3jDbwRixcX6vKMXt7gxswVQASSQBdTN0Kk2bn1S217Ner0ST_cxWoie8EJBIkF58cbnPZ26LZ8pr9Nob34D3QuU6ZZ4UUOnuKNfyyPvngp2Wjqnh8xCW-urSpd3hTuTjiWoud5oGrVcdsj3TzOwnzANUfn-lENbfva3c96vbr4-cxWblVWfM1PR56LaNvy9u_jODUN_67lmpp6BVyuYcmivhbwygyxV6bSJn6EbK9a-_fiGU4hqnDib8zZTdSHnq4PlvWVa3V6j2u56BXMErQPKIs2PB_BQSbcVFiFMDjq0q0wI-blKJsQ9cDIp4fjc5V2iNb1mIveen69RBiyQkrkr6pylpwZNVPg_K6tXkkBZvw89vd6OVuN7adhLGEpbGZbvfmmIrrJuV83ICVLplYDqZp5jqKbE93teSd7CtQdd8Kl6RG7TEApYP0eq6ixnocxRKqt57CTUTtIoSbJiD4JenvIo9OQV9gx0Emw0vIwmfNTEa3sbCOPMA4iPjCkJuUcVgtVi21GdOwWSgAQTAPnYmHr-rwy55oon4jp5IqVeAdKPDabmx7BqqutO1rNe1AxVmDo7Sl03iJ5FSZuXxrtqblj4Dm-WY98ge9vU2mSjcYh1jGucP7cmBPy_it6F4fOqGN_Gh9XvzRX43olY_s229rQlk2DvdXUHSlkBp8dYaVlhqxy-SZ5mZxT1tf8Lu_Xbkb6M7EtJqjTy70yPg ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="1264218016" data-image-id="95853799" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="8|1264218016|EC||LOCAL|1285.71" data-os-property-id="1264218016" data-os-property-image-id="95853799" data-os-property-rank="7" data-pimms="DoubleStamps|D13" data-provider-type="LOCAL" data-title="North Shores Inn"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho1264218016/?pa=8&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">North Shores Inn</a></h3><address class="contact"><span class="address" dir="ltr">Barangay Victoria, Currimao, Ilocos Norte, 2903, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho1264218016/?pa=8&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="North Shores Inn, Currimao" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/40000000/39480000/39475600/39475563/5f5fc96a_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="North Shores Inn, Currimao" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/40000000/39480000/39475600/39475563/5f5fc96a_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="North Shores Inn, Currimao" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/40000000/39480000/39475600/39475563/5f5fc96a_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">2.5-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho1264218016/?pa=8&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Currimao</a><ul class="property-landmarks"><li>360 km to Subic Bay</li><li>390 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity parkingOptions">Free parking</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-very-good">Very good 8.0</strong><a class="guest-reviews-link reviews-link" href="/ho1264218016/?pa=8&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">1 review</span><span class="full-view">1 Hotels.com guest review</span></a></div></div></div><aside class="pricing resp-module"><div class="price"><a class="price-link" href="/ho1264218016/?pa=8&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0#rooms-and-rates-a ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Guest House" data-hotel-id="647928512" data-image-id="405961490" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="9|647928512|EC||LOCAL|723.21" data-os-property-id="647928512" data-os-property-image-id="405961490" data-os-property-rank="8" data-pimms="DoubleStamps|D13|TESCO" data-provider-type="LOCAL" data-title="Pabua's Cottages"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><span class="vr-badge">Guest house</span><a class="property-name-link" href="/ho647928512/?pa=9&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Pabua's Cottages</a></h3><address class="contact"><span class="address" dir="ltr">Rocky Village, Yumbing, Mambajao, 9100, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho647928512/?pa=9&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Pabua's Cottages, Mambajao" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/21000000/20220000/20216600/20216516/1778f49b_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Pabua's Cottages, Mambajao" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/21000000/20220000/20216600/20216516/1778f49b_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Pabua's Cottages, Mambajao" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/21000000/20220000/20216600/20216516/1778f49b_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">2.5-star</span><div class="location-info resp-module"><a class="map-link" href="/ho647928512/?pa=9&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Mambajao</a><ul class="property-landmarks"><li>780 km to Subic Bay</li><li>710 km to Manila Bay</li></ul></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity parkingOptions">Free parking</li><li class="hmvt8258-amenity airportTransfer">Airport transfer</li><li class="hmvt8258-amenity bed">Connecting rooms available</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-fabulous">Fabulous 8.6</strong><a class="guest-reviews-link reviews-link" href="/ho647928512/?pa=9&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">41 reviews</span><span class="full-view">41 Hotels.com guest reviews</span></a></div></div></div><aside class="pricing resp-module dynamic-percentage-off"><p class="percentage-off"><span class="percentage">10% off</span></p><strong class="special-deal widget-tooltip widget-tooltip-tl widget-tooltip-multiline" data-drr-id="DRR-446" tabindex="0"><span class="special-deal-badge">Special Deal</span><span class="widget-tooltip-bd">Save 10%</span></strong><div class="price"><di ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="431229" data-image-id="7990371" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="10|431229|EC||LOCAL|1240.49" data-os-property-id="431229" data-os-property-image-id="7990371" data-os-property-rank="9" data-pimms="newhotel|DoubleStamps|D13|TESCO" data-provider-type="LOCAL" data-title="Angelic Mansion"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho431229/?pa=10&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Angelic Mansion</a></h3><span class="hotel-badge" data-badge-type="justAdded">Just added</span><address class="contact"><span class="address" dir="ltr">Wescom Road, Barangay San Pedro, Puerto Princesa, Palawan, 5300, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho431229/?pa=10&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Angelic Mansion, Puerto Princesa" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/7000000/6050000/6049900/6049853/71ecd4cd_y.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Angelic Mansion, Puerto Princesa" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/7000000/6050000/6049900/6049853/71ecd4cd_y.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Angelic Mansion, Puerto Princesa" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/7000000/6050000/6049900/6049853/71ecd4cd_y.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">3-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho431229/?pa=10&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Puerto Princesa City Centre</a><ul class="property-landmarks"><li>580 km to Subic Bay</li><li>580 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity pool">Pool</li><li class="hmvt8258-amenity parkingOptions">Free parking</li><li class="hmvt8258-amenity airportTransfer">Airport transfer</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-very-good">Very good 8.4</strong><a class="guest-reviews-link reviews-link" href="/ho431229/?pa=10&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">11 reviews</span><span class="full-view">11 Hotels.com guest reviews</span></a></div></div></div><aside class="pricing resp-module dynamic-percentage-off"><p class="percentage-off"><spa ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="596781568" data-image-id="77752017" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="11|596781568|EC||LOCAL|8536" data-os-property-id="596781568" data-os-property-image-id="77752017" data-os-property-rank="10" data-pimms="DoubleStamps|TESCO" data-provider-type="LOCAL" data-title="Grand Hyatt Manila"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho596781568/?pa=11&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Grand Hyatt Manila</a></h3><span class="hotel-badge" data-badge-type="lovedByGuests">Loved by guests</span><address class="contact"><span class="address" dir="ltr">36th Street, corner 8th Avenue, Bonifacio Global City, Taguig, Manila, 1634, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho596781568/?pa=11&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="Grand Hyatt Manila, Taguig" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/19000000/18620000/18618200/18618174/631066b4_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="Grand Hyatt Manila, Taguig" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/19000000/18620000/18618200/18618174/631066b4_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="Grand Hyatt Manila, Taguig" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/19000000/18620000/18618200/18618174/631066b4_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text star-rating-text-strong">5-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho596781568/?pa=11&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Bonifacio Global City</a><ul class="property-landmarks"><li>92 km to Subic Bay</li><li>11 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div><ul class="hmvt8258-amenities"><li class="hmvt8258-amenity pool">Pool</li><li class="hmvt8258-amenity parkingOptions">Free parking</li><li class="hmvt8258-amenity spa">Spa</li><li class="hmvt8258-amenity gym">Gym</li><li class="hmvt8258-amenity restaurant">Restaurant</li><li class="hmvt8258-amenity bar">Bar</li></ul></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-superb">Superb 9.2</strong><a class="guest-reviews-link reviews-link" href="/ho596781568/?pa=11&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">248 reviews</span><span class="ful ...
#  <li class="hotel" data-accommodation-type="_ACC_TYPE_NAME@Hotel" data-hotel-id="1441288448" data-image-id="372711158" data-image-tracking="DataScience|$#|herobandit.v20201116-contextual-heroaesthetics.v20200130-hsc.v20190223|$#|20210409" data-info="12|1441288448|Dual||LOCAL|594.55" data-os-property-id="1441288448" data-os-property-image-id="372711158" data-os-property-rank="11" data-pimms="DoubleStamps|D13" data-provider-type="LOCAL" data-title="RedDoorz Plus near Bangko Sentral ng Pilipinas Davao"><article><section class="hotel-wrap"><div class="description resp-module"><h3 class="p-name"><a class="property-name-link" href="/ho1441288448/?pa=12&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">RedDoorz Plus near Bangko Sentral ng Pilipinas Davao</a></h3><address class="contact"><span class="address" dir="ltr">Emilio Jacinto Ext., Corner Arellano St., Davao, 8010, Philippines</span></address><figure class="image"><a class="property-image-link" href="/ho1441288448/?pa=12&amp;q-check-out=2021-10-11&amp;tab=description&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><img alt="RedDoorz Plus near Bangko Sentral ng Pilipinas Davao, Davao" class="u-photo use-bgimage image-loader featured-img-desktop" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/46000000/45010000/45009100/45009014/e897277c_z.jpg?impolicy=fcrop&amp;w=250&amp;h=140&amp;q=high')"/><img alt="RedDoorz Plus near Bangko Sentral ng Pilipinas Davao, Davao" class="u-photo use-bgimage image-loader featured-img-tablet" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/46000000/45010000/45009100/45009014/e897277c_z.jpg?impolicy=fcrop&amp;w=154&amp;h=84&amp;q=high')"/><img alt="RedDoorz Plus near Bangko Sentral ng Pilipinas Davao, Davao" class="u-photo use-bgimage image-loader featured-img-mobile" src="https://a.cdn-hotels.com/uswest2/da/assets/s/63.0.10760/images/common/core/dio/widget/1.gif" style="background-image:url('https://exp.cdn-hotels.com/hotels/46000000/45010000/45009100/45009014/e897277c_z.jpg?impolicy=fcrop&amp;w=180&amp;h=270&amp;q=high')"/></a></figure><div class="details resp-module"><div class="additional-details resp-module"><span class="star-rating-text">3-star</span><div class="location-info resp-module"><a class="map-link xs-welcome-rewards" href="/ho1441288448/?pa=12&amp;q-check-out=2021-10-11&amp;tab=maps&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank">Poblacion District</a><ul class="property-landmarks"><li>1000 km to Subic Bay</li><li>970 km to Manila Bay</li></ul></div><div class="welcome-rewards widget-tooltip widget-tooltip-tr" tabindex="0"><span class="hr-live-text">Collect stamps</span><span class="widget-tooltip-bd">Collect 10 nights, get 1 reward* night with Hotels.com™ Rewards</span></div></div><div class="reviews-box resp-module"><strong class="guest-reviews-badge guest-rating-exceptional">Exceptional 10.0</strong><a class="guest-reviews-link reviews-link" href="/ho1441288448/?pa=12&amp;q-check-out=2021-10-11&amp;tab=reviews&amp;q-room-0-adults=2&amp;YGF=14&amp;q-check-in=2021-10-10&amp;MGT=1&amp;WOE=1&amp;WOD=7&amp;ZSX=0&amp;SYE=3&amp;q-room-0-children=0" target="_blank"><span class="small-view">1 review</span><span class="full-view">1 Hotels.com guest review</span></a></div></div></div><aside class="pricing resp-module dynamic-percentage-off"><p class="percentage-off"><span class="percentage">20% off</span></p><strong class="special-deal widget-tooltip widget-tooltip-tl widget-t ...
#  <li><img alt="" class="hidden-tracking-pixel" src="https://www.egadvertising.com/travelAds/v1/TravelAdPageView?deviceType=Desktop&amp;sort-order=BEST_SELLER&amp;rooms=1&amp;destRegionID=10233139&amp;hotelIds=113079,384361024,974390240,595231,940450912,478447,1130186432,1264218016,647928512,431229,596781568,1441288448&amp;adults=2&amp;userAgent=Mozilla/5.0%20%28Windows%20NT%2010.0;%20Win64;%20x64%29%20AppleWebKit/537.36%20%28KHTML,%20like%20Gecko%29%20Chrome/89.0.4389.114%20Safari/537.36&amp;userGuid=bec0e309-a3c9-4cf7-afd9-3d9210a47ed0&amp;pageName=Hotel-Search&amp;slots=HSR_A,HSR_B,HSR_C,HSR_D,HSR_E&amp;checkIn=2021-10-10&amp;children=0&amp;culture=en_PH&amp;testVersionOverride=4961.0,904.0,7561.0,7215.1,8218.0,8711.2,8928.3,9008.0,8347.0,9004.0,8952.0,7992.2,8915.0,9729.1,9716.0,9864.0,9945.0,10155.1,9884.0,10185.0&amp;domain=ph.hotels.com&amp;tac=true&amp;userIP=112.198.222.98&amp;action=pageview&amp;publisher=expedia&amp;checkOut=2021-10-11&amp;programId=1"/></li>]

# %%
df = init_df()

# %%
p[0]['data-title']
# Out:
# 'The Heritage Hotel Manila'

# %%
hotel = Hotel(p[0],df)    # sa internet ata
hotel.__dict__

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
